# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_key import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# pip install citypy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# pip install citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 607

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

response = requests.get(query_url + ('Grand Junction')).json()

response
# Out:
# {'coord': {'lon': -108.55, 'lat': 39.06},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 36.31,
#   'feels_like': 32.63,
#   'temp_min': 36,
#   'temp_max': 36.67,
#   'pressure': 1020,
#   'humidity': 9},
#  'visibility': 10000,
#  'wind': {'speed': 2.1, 'deg': 260},
#  'clouds': {'all': 1},
#  'dt': 1596313893,
#  'sys': {'type': 1,
#   'id': 4219,
#   'country': 'US',
#   'sunrise': 1596284116,
#   'sunset': 1596335135},
#  'timezone': -21600,
#  'id': 5423573,
#  'name': 'Grand Junction',
#  'cod': 200}

# %% [markdown]
# # Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

lat = []
lng=[]
temp = []
Humidity= []
Cloudiness = []
Wind_Speed =[]
city=[]
country=[]
number = 1
sets = 1 

print(f"Begining Data Retrieval:\n-----------------------------")
# Loop through the list of cities and perform a request for data on each
 
for citi in cities:
    try:
        response = requests.get(query_url + (citi)).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        country.append(response['sys']['country'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        city.append(response['name'])
        print(f"Processing Record {number} Set {sets}- {citi}")
        number=number+1
        if (number % 51 == 0):
            sets=sets+1
            number=1
    except KeyError:
        print('An error occurred skipping.. ')

print('complete')
        

# response
# Out:
# Begining Data Retrieval:
# -----------------------------
# Processing Record 1 Set 1- dubrovnik
# Processing Record 2 Set 1- esso
# Processing Record 3 Set 1- port augusta
# Processing Record 4 Set 1- lompoc
# Processing Record 5 Set 1- vila franca do campo
# Processing Record 6 Set 1- avarua
# Processing Record 7 Set 1- punta arenas
# Processing Record 8 Set 1- cape town
# Processing Record 9 Set 1- ushuaia
# Processing Record 10 Set 1- mendeleyevo
# Processing Record 11 Set 1- vaini
# Processing Record 12 Set 1- kawalu
# Processing Record 13 Set 1- sitka
# Processing Record 14 Set 1- praia da vitoria
# Processing Record 15 Set 1- tasiilaq
# An error occurred skipping..
# Processing Record 16 Set 1- dalvik
# Processing Record 17 Set 1- atuona
# Processing Record 18 Set 1- codrington
# Processing Record 19 Set 1- bredasdorp
# Processing Record 20 Set 1- flinders
# Processing Record 21 Set 1- imbituba
# Processing Record 22 Set 1- beringovskiy
# Processing Record 23 Set 1- kavieng
# Processing Record 24 Set 1- puerto ayora
# An error occurred skipping..
# Processing Record 25 Set 1- visnes
# Processing Record 26 Set 1- cherskiy
# Processing Record 27 Set 1- chuy
# Processing Record 28 Set 1- novopskov
# Processing Record 29 Set 1- lazaro cardenas
# Processing Record 30 Set 1- mahebourg
# Processing Record 31 Set 1- ayan
# An error occurred skipping..
# Processing Record 32 Set 1- port elizabeth
# Processing Record 33 Set 1- chara
# Processing Record 34 Set 1- adrar
# Processing Record 35 Set 1- lasa
# Processing Record 36 Set 1- barrow
# Processing Record 37 Set 1- joshimath
# Processing Record 38 Set 1- mitsamiouli
# Processing Record 39 Set 1- castro
# Processing Record 40 Set 1- georgetown
# Processing Record 41 Set 1- borinskoye
# Processing Record 42 Set 1- puertollano
# Processing Record 43 Set 1- los llanos de aridane
# Processing Record 44 Set 1- meaford
# Processing Record 45 Set 1- ekhabi
# Processing Record 46 Set 1- sur
# Processing Record 47 Set 1- tual
# Processing Record 48 Set 1- tuktoyaktuk
# Processing Record 49 Set 1- havoysund
# Processing Record 50 Set 1- codajas
# Processing Record 1 Set 2- kaitangata
# Processing Record 2 Set 2- katsuura
# Processing Record 3 Set 2- playas
# Processing Record 4 Set 2- nome
# Processing Record 5 Set 2- mezen
# Processing Record 6 Set 2- fairbanks
# Processing Record 7 Set 2- fallon
# Processing Record 8 Set 2- busselton
# Processing Record 9 Set 2- butaritari
# Processing Record 10 Set 2- pucallpa
# Processing Record 11 Set 2- hoa binh
# Processing Record 12 Set 2- hermanus
# Processing Record 13 Set 2- lashio
# Processing Record 14 Set 2- hithadhoo
# Processing Record 15 Set 2- bilibino
# Processing Record 16 Set 2- bandarbeyla
# Processing Record 17 Set 2- chokurdakh
# Processing Record 18 Set 2- victoria
# Processing Record 19 Set 2- pemangkat
# Processing Record 20 Set 2- lagoa
# Processing Record 21 Set 2- albany
# Processing Record 22 Set 2- ketchikan
# Processing Record 23 Set 2- olkhovatka
# Processing Record 24 Set 2- kodiak
# Processing Record 25 Set 2- rikitea
# Processing Record 26 Set 2- tilichiki
# Processing Record 27 Set 2- cidreira
# Processing Record 28 Set 2- san carlos del zulia
# Processing Record 29 Set 2- mataura
# Processing Record 30 Set 2- alice springs
# Processing Record 31 Set 2- bubaque
# Processing Record 32 Set 2- rundu
# Processing Record 33 Set 2- provideniya
# Processing Record 34 Set 2- pierre
# Processing Record 35 Set 2- qaanaaq
# Processing Record 36 Set 2- yonago
# Processing Record 37 Set 2- souillac
# Processing Record 38 Set 2- ust-kulom
# Processing Record 39 Set 2- sistranda
# Processing Record 40 Set 2- ponta delgada
# Processing Record 41 Set 2- vestmannaeyjar
# Processing Record 42 Set 2- ubauro
# Processing Record 43 Set 2- bambous virieux
# Processing Record 44 Set 2- saskylakh
# Processing Record 45 Set 2- kapaa
# An error occurred skipping..
# Processing Record 46 Set 2- tambilil
# Processing Record 47 Set 2- san patricio
# An error occurred skipping..
# Processing Record 48 Set 2- batticaloa
# Processing Record 49 Set 2- phan thiet
# Processing Record 50 Set 2- bluff
# Processing Record 1 Set 3- saint-philippe
# Processing Record 2 Set 3- carnarvon
# Processing Record 3 Set 3- nikolskoye
# Processing Record 4 Set 3- najran
# Processing Record 5 Set 3- nenjiang
# Processing Record 6 Set 3- port keats
# Processing Record 7 Set 3- yellowknife
# Processing Record 8 Set 3- half moon bay
# Processing Record 9 Set 3- hobart
# Processing Record 10 Set 3- clyde river
# Processing Record 11 Set 3- sedlcany
# Processing Record 12 Set 3- lavrentiya
# Processing Record 13 Set 3- cabedelo
# Processing Record 14 Set 3- grindavik
# Processing Record 15 Set 3- saint anthony
# Processing Record 16 Set 3- matagami
# Processing Record 17 Set 3- port lincoln
# An error occurred skipping..
# Processing Record 18 Set 3- soyo
# An error occurred skipping..
# An error occurred skipping..
# Processing Record 19 Set 3- novyy urengoy
# Processing Record 20 Set 3- mokhsogollokh
# Processing Record 21 Set 3- peace river
# Processing Record 22 Set 3- hilo
# Processing Record 23 Set 3- port alfred
# Processing Record 24 Set 3- linares
# Processing Record 25 Set 3- zhaodong
# Processing Record 26 Set 3- makokou
# Processing Record 27 Set 3- te anau
# Processing Record 28 Set 3- kupino
# Processing Record 29 Set 3- severo-kurilsk
# Processing Record 30 Set 3- itoman
# Processing Record 31 Set 3- cabo san lucas
# Processing Record 32 Set 3- ahipara
# Processing Record 33 Set 3- socorro
# Processing Record 34 Set 3- khatanga
# Processing Record 35 Set 3- balkanabat
# Processing Record 36 Set 3- bakersfield
# Processing Record 37 Set 3- jiexiu
# Processing Record 38 Set 3- pemba
# Processing Record 39 Set 3- dikson
# Processing Record 40 Set 3- jamestown
# Processing Record 41 Set 3- san cristobal
# Processing Record 42 Set 3- colonia
# Processing Record 43 Set 3- hasaki
# Processing Record 44 Set 3- college
# Processing Record 45 Set 3- saint-georges
# Processing Record 46 Set 3- semenyih
# Processing Record 47 Set 3- okha
# Processing Record 48 Set 3- geraldton
# Processing Record 49 Set 3- piraju
# Processing Record 50 Set 3- bethel
# An error occurred skipping..
# Processing Record 1 Set 4- el sauce
# Processing Record 2 Set 4- abeche
# Processing Record 3 Set 4- creel
# Processing Record 4 Set 4- encantado
# Processing Record 5 Set 4- upernavik
# Processing Record 6 Set 4- bereda
# Processing Record 7 Set 4- hihya
# Processing Record 8 Set 4- sakaiminato
# Processing Record 9 Set 4- monrovia
# Processing Record 10 Set 4- aklavik
# Processing Record 11 Set 4- moose factory
# Processing Record 12 Set 4- qasigiannguit
# Processing Record 13 Set 4- bow island
# Processing Record 14 Set 4- ribeira grande
# Processing Record 15 Set 4- sao joao da barra
# Processing Record 16 Set 4- tiksi
# Processing Record 17 Set 4- mayskiy
# Processing Record 18 Set 4- homer
# Processing Record 19 Set 4- yar-sale
# Processing Record 20 Set 4- hamilton
# Processing Record 21 Set 4- tianpeng
# Processing Record 22 Set 4- kruisfontein
# Processing Record 23 Set 4- trinidad
# An error occurred skipping..
# Processing Record 24 Set 4- iqaluit
# Processing Record 25 Set 4- airai
# Processing Record 26 Set 4- padang
# Processing Record 27 Set 4- mar del plata
# Processing Record 28 Set 4- jaragua
# An error occurred skipping..
# An error occurred skipping..
# Processing Record 29 Set 4- coria
# Processing Record 30 Set 4- bedesa
# Processing Record 31 Set 4- danielskuil
# Processing Record 32 Set 4- arraial do cabo
# Processing Record 33 Set 4- ula
# Processing Record 34 Set 4- bathsheba
# Processing Record 35 Set 4- roebourne
# Processing Record 36 Set 4- buenos aires
# Processing Record 37 Set 4- kavaratti
# Processing Record 38 Set 4- maarianhamina
# Processing Record 39 Set 4- winchester
# Processing Record 40 Set 4- owando
# Processing Record 41 Set 4- bengkulu
# Processing Record 42 Set 4- vilhena
# Processing Record 43 Set 4- lebu
# Processing Record 44 Set 4- estelle
# An error occurred skipping..
# Processing Record 45 Set 4- komsomolskiy
# Processing Record 46 Set 4- alofi
# Processing Record 47 Set 4- new norfolk
# Processing Record 48 Set 4- waddan
# Processing Record 49 Set 4- nouadhibou
# Processing Record 50 Set 4- tamandare
# Processing Record 1 Set 5- labuhan
# Processing Record 2 Set 5- umm lajj
# Processing Record 3 Set 5- telford
# Processing Record 4 Set 5- mbuji-mayi
# Processing Record 5 Set 5- ilulissat
# Processing Record 6 Set 5- nizhnevartovsk
# Processing Record 7 Set 5- husavik
# Processing Record 8 Set 5- maniitsoq
# Processing Record 9 Set 5- springbok
# Processing Record 10 Set 5- san nicolas
# Processing Record 11 Set 5- saldanha
# Processing Record 12 Set 5- talnakh
# Processing Record 13 Set 5- ponta do sol
# Processing Record 14 Set 5- pevek
# Processing Record 15 Set 5- roald
# Processing Record 16 Set 5- verkhozim
# Processing Record 17 Set 5- deori
# Processing Record 18 Set 5- manokwari
# Processing Record 19 Set 5- palmer
# Processing Record 20 Set 5- iranshahr
# Processing Record 21 Set 5- makat
# Processing Record 22 Set 5- makakilo city
# Processing Record 23 Set 5- pechora
# Processing Record 24 Set 5- vila velha
# Processing Record 25 Set 5- dingle
# Processing Record 26 Set 5- parana
# Processing Record 27 Set 5- saint george
# Processing Record 28 Set 5- anadyr
# Processing Record 29 Set 5- brandon
# Processing Record 30 Set 5- longyearbyen
# Processing Record 31 Set 5- richards bay
# Processing Record 32 Set 5- torbay
# Processing Record 33 Set 5- port hardy
# Processing Record 34 Set 5- narsaq
# Processing Record 35 Set 5- ondjiva
# Processing Record 36 Set 5- senador pompeu
# Processing Record 37 Set 5- manali
# Processing Record 38 Set 5- touros
# Processing Record 39 Set 5- letlhakane
# Processing Record 40 Set 5- riverton
# Processing Record 41 Set 5- thessalon
# Processing Record 42 Set 5- leningradskiy
# Processing Record 43 Set 5- walvis bay
# Processing Record 44 Set 5- senador guiomard
# Processing Record 45 Set 5- whitecourt
# Processing Record 46 Set 5- macomb
# Processing Record 47 Set 5- sanlucar la mayor
# An error occurred skipping..
# Processing Record 48 Set 5- cockburn town
# Processing Record 49 Set 5- port hawkesbury
# Processing Record 50 Set 5- surovikino
# Processing Record 1 Set 6- kieta
# Processing Record 2 Set 6- freiburg
# Processing Record 3 Set 6- omagh
# Processing Record 4 Set 6- melville
# Processing Record 5 Set 6- tagusao
# Processing Record 6 Set 6- slave lake
# Processing Record 7 Set 6- kovdor
# Processing Record 8 Set 6- minnedosa
# Processing Record 9 Set 6- santa ana
# Processing Record 10 Set 6- dhoraji
# Processing Record 11 Set 6- east london
# Processing Record 12 Set 6- mahibadhoo
# Processing Record 13 Set 6- teya
# Processing Record 14 Set 6- muroto
# Processing Record 15 Set 6- meulaboh
# Processing Record 16 Set 6- salalah
# Processing Record 17 Set 6- plaster rock
# Processing Record 18 Set 6- shache
# Processing Record 19 Set 6- juneau
# Processing Record 20 Set 6- norman wells
# Processing Record 21 Set 6- guerrero negro
# Processing Record 22 Set 6- tiznit
# Processing Record 23 Set 6- helong
# Processing Record 24 Set 6- coihaique
# Processing Record 25 Set 6- hamburg
# Processing Record 26 Set 6- amasia
# Processing Record 27 Set 6- ust-nera
# Processing Record 28 Set 6- mashhad
# Processing Record 29 Set 6- kahului
# Processing Record 30 Set 6- lorengau
# Processing Record 31 Set 6- klaksvik
# Processing Record 32 Set 6- khaga
# Processing Record 33 Set 6- channagiri
# Processing Record 34 Set 6- hirado
# Processing Record 35 Set 6- altay
# Processing Record 36 Set 6- kavali
# Processing Record 37 Set 6- esperance
# Processing Record 38 Set 6- braganca paulista
# Processing Record 39 Set 6- matola
# Processing Record 40 Set 6- lugovoy
# Processing Record 41 Set 6- hambantota
# Processing Record 42 Set 6- almaznyy
# Processing Record 43 Set 6- rawson
# Processing Record 44 Set 6- yen bai
# Processing Record 45 Set 6- thompson
# An error occurred skipping..
# Processing Record 46 Set 6- beloha
# Processing Record 47 Set 6- jumla
# Processing Record 48 Set 6- dhilwan
# An error occurred skipping..
# An error occurred skipping..
# Processing Record 49 Set 6- frontera
# Processing Record 50 Set 6- paamiut
# An error occurred skipping..
# Processing Record 1 Set 7- nicoya
# Processing Record 2 Set 7- kautokeino
# An error occurred skipping..
# Processing Record 3 Set 7- santa rosa
# An error occurred skipping..
# Processing Record 4 Set 7- gondanglegi
# Processing Record 5 Set 7- le port
# Processing Record 6 Set 7- banjar
# Processing Record 7 Set 7- neiafu
# Processing Record 8 Set 7- paka
# Processing Record 9 Set 7- mayo
# Processing Record 10 Set 7- aripuana
# Processing Record 11 Set 7- kununurra
# Processing Record 12 Set 7- nuevo progreso
# Processing Record 13 Set 7- sampit
# Processing Record 14 Set 7- los barrios
# Processing Record 15 Set 7- tromso
# Processing Record 16 Set 7- mareeba
# Processing Record 17 Set 7- pangnirtung
# Processing Record 18 Set 7- berlevag
# Processing Record 19 Set 7- moen
# Processing Record 20 Set 7- butka
# Processing Record 21 Set 7- madras
# Processing Record 22 Set 7- hudiksvall
# Processing Record 23 Set 7- bideford
# Processing Record 24 Set 7- champerico
# Processing Record 25 Set 7- ancud
# Processing Record 26 Set 7- grand-lahou
# Processing Record 27 Set 7- sechura
# Processing Record 28 Set 7- vardo
# Processing Record 29 Set 7- bolobo
# Processing Record 30 Set 7- taoudenni
# An error occurred skipping..
# Processing Record 31 Set 7- turukhansk
# Processing Record 32 Set 7- cayenne
# Processing Record 33 Set 7- harper
# Processing Record 34 Set 7- faanui
# An error occurred skipping..
# Processing Record 35 Set 7- fort nelson
# Processing Record 36 Set 7- simao
# Processing Record 37 Set 7- tshikapa
# Processing Record 38 Set 7- kailua
# Processing Record 39 Set 7- kiruna
# Processing Record 40 Set 7- walla walla
# Processing Record 41 Set 7- kalmunai
# Processing Record 42 Set 7- biskamzha
# Processing Record 43 Set 7- valparaiso
# Processing Record 44 Set 7- lishui
# Processing Record 45 Set 7- caravelas
# Processing Record 46 Set 7- dong hoi
# Processing Record 47 Set 7- vinukonda
# Processing Record 48 Set 7- mantena
# Processing Record 49 Set 7- fukue
# Processing Record 50 Set 7- north bend
# Processing Record 1 Set 8- san quintin
# Processing Record 2 Set 8- terralba
# Processing Record 3 Set 8- karratha
# Processing Record 4 Set 8- tevaitoa
# Processing Record 5 Set 8- fevik
# Processing Record 6 Set 8- lugoba
# Processing Record 7 Set 8- inhambane
# Processing Record 8 Set 8- naze
# An error occurred skipping..
# Processing Record 9 Set 8- hami
# Processing Record 10 Set 8- yaring
# Processing Record 11 Set 8- tambura
# Processing Record 12 Set 8- shakawe
# Processing Record 13 Set 8- morristown
# Processing Record 14 Set 8- panzhihua
# Processing Record 15 Set 8- malpur
# Processing Record 16 Set 8- kurilsk
# An error occurred skipping..
# Processing Record 17 Set 8- alugan
# An error occurred skipping..
# Processing Record 18 Set 8- chabahar
# An error occurred skipping..
# An error occurred skipping..
# Processing Record 19 Set 8- sola
# Processing Record 20 Set 8- itarema
# Processing Record 21 Set 8- sarangani
# Processing Record 22 Set 8- faya
# Processing Record 23 Set 8- burghausen
# An error occurred skipping..
# Processing Record 24 Set 8- buraydah
# Processing Record 25 Set 8- ganzhou
# Processing Record 26 Set 8- sainte-marie
# Processing Record 27 Set 8- omsukchan
# Processing Record 28 Set 8- biggar
# An error occurred skipping..
# Processing Record 29 Set 8- honiara
# Processing Record 30 Set 8- san juan evangelista
# An error occurred skipping..
# Processing Record 31 Set 8- nagato
# Processing Record 32 Set 8- olafsvik
# Processing Record 33 Set 8- ola
# Processing Record 34 Set 8- tirau
# Processing Record 35 Set 8- kuytun
# Processing Record 36 Set 8- laguna
# Processing Record 37 Set 8- khash
# Processing Record 38 Set 8- verkhoyansk
# Processing Record 39 Set 8- goundam
# Processing Record 40 Set 8- kemijarvi
# Processing Record 41 Set 8- tocopilla
# Processing Record 42 Set 8- luderitz
# Processing Record 43 Set 8- yumen
# Processing Record 44 Set 8- kribi
# Processing Record 45 Set 8- muros
# An error occurred skipping..
# Processing Record 46 Set 8- la ronge
# Processing Record 47 Set 8- zhuji
# Processing Record 48 Set 8- batagay-alyta
# Processing Record 49 Set 8- tarancon
# Processing Record 50 Set 8- onega
# Processing Record 1 Set 9- sangar
# Processing Record 2 Set 9- misratah
# Processing Record 3 Set 9- kpandae
# Processing Record 4 Set 9- wajima
# Processing Record 5 Set 9- teahupoo
# Processing Record 6 Set 9- kefamenanu
# Processing Record 7 Set 9- pouembout
# Processing Record 8 Set 9- zhigansk
# Processing Record 9 Set 9- kloulklubed
# Processing Record 10 Set 9- sorong
# Processing Record 11 Set 9- merauke
# Processing Record 12 Set 9- anzio
# Processing Record 13 Set 9- meridian
# Processing Record 14 Set 9- brae
# Processing Record 15 Set 9- puerto escondido
# Processing Record 16 Set 9- hurghada
# Processing Record 17 Set 9- villefontaine
# Processing Record 18 Set 9- yerbogachen
# Processing Record 19 Set 9- horsham
# Processing Record 20 Set 9- uong bi
# An error occurred skipping..
# Processing Record 21 Set 9- darhan
# Processing Record 22 Set 9- tura
# Processing Record 23 Set 9- altamira
# Processing Record 24 Set 9- palana
# Processing Record 25 Set 9- gilbues
# Processing Record 26 Set 9- hofn
# Processing Record 27 Set 9- kitgum
# An error occurred skipping..
# Processing Record 28 Set 9- qaqortoq
# Processing Record 29 Set 9- balrampur
# Processing Record 30 Set 9- seymchan
# Processing Record 31 Set 9- mecca
# Processing Record 32 Set 9- gusau
# Processing Record 33 Set 9- puerto carreno
# Processing Record 34 Set 9- coquimbo
# Processing Record 35 Set 9- manono
# Processing Record 36 Set 9- gamba
# Processing Record 37 Set 9- nizhniy tsasuchey
# Processing Record 38 Set 9- nanortalik
# Processing Record 39 Set 9- santa cruz de tenerife
# Processing Record 40 Set 9- atbasar
# Processing Record 41 Set 9- nemuro
# Processing Record 42 Set 9- henties bay
# Processing Record 43 Set 9- gayny
# Processing Record 44 Set 9- hit
# Processing Record 45 Set 9- piacabucu
# Processing Record 46 Set 9- naliya
# Processing Record 47 Set 9- kampot
# Processing Record 48 Set 9- ondangwa
# Processing Record 49 Set 9- vidim
# Processing Record 50 Set 9- salisbury
# Processing Record 1 Set 10- yurimaguas
# Processing Record 2 Set 10- fortuna
# Processing Record 3 Set 10- tabas
# Processing Record 4 Set 10- avera
# Processing Record 5 Set 10- lesnoy
# Processing Record 6 Set 10- muisne
# Processing Record 7 Set 10- udachnyy
# Processing Record 8 Set 10- namibe
# Processing Record 9 Set 10- kirkwood
# Processing Record 10 Set 10- egvekinot
# Processing Record 11 Set 10- victor harbor
# An error occurred skipping..
# Processing Record 12 Set 10- ostrovnoy
# Processing Record 13 Set 10- kamenka
# Processing Record 14 Set 10- nha trang
# Processing Record 15 Set 10- huilong
# Processing Record 16 Set 10- mackay
# Processing Record 17 Set 10- mwene-ditu
# Processing Record 18 Set 10- sinnamary
# Processing Record 19 Set 10- sukumo
# Processing Record 20 Set 10- the valley
# Processing Record 21 Set 10- sao filipe
# Processing Record 22 Set 10- yunyang
# Processing Record 23 Set 10- hobyo
# Processing Record 24 Set 10- constitucion
# Processing Record 25 Set 10- raga
# Processing Record 26 Set 10- eyl
# Processing Record 27 Set 10- limbuhan
# Processing Record 28 Set 10- vila
# Processing Record 29 Set 10- leh
# Processing Record 30 Set 10- barao de melgaco
# Processing Record 31 Set 10- flin flon
# Processing Record 32 Set 10- saint-joseph
# Processing Record 33 Set 10- mount isa
# Processing Record 34 Set 10- porto novo
# Processing Record 35 Set 10- preobrazheniye
# An error occurred skipping..
# Processing Record 36 Set 10- benguela
# Processing Record 37 Set 10- haines junction
# Processing Record 38 Set 10- kenai
# Processing Record 39 Set 10- masterton
# Processing Record 40 Set 10- strezhevoy
# Processing Record 41 Set 10- kosa
# Processing Record 42 Set 10- vao
# Processing Record 43 Set 10- sechelt
# Processing Record 44 Set 10- tharad
# Processing Record 45 Set 10- granja
# Processing Record 46 Set 10- yining
# Processing Record 47 Set 10- auki
# Processing Record 48 Set 10- asau
# Processing Record 49 Set 10- tortoli
# Processing Record 50 Set 10- mwanza
# Processing Record 1 Set 11- pacific grove
# Processing Record 2 Set 11- imamoglu
# Processing Record 3 Set 11- holland
# Processing Record 4 Set 11- isangel
# Processing Record 5 Set 11- belmonte
# Processing Record 6 Set 11- carutapera
# Processing Record 7 Set 11- cochrane
# Processing Record 8 Set 11- shivrajpur
# Processing Record 9 Set 11- magway
# Processing Record 10 Set 11- pimentel
# Processing Record 11 Set 11- dhidhdhoo
# Processing Record 12 Set 11- mmathubudukwane
# Processing Record 13 Set 11- rio grande
# An error occurred skipping..
# Processing Record 14 Set 11- goderich
# Processing Record 15 Set 11- sulangan
# Processing Record 16 Set 11- corinth
# Processing Record 17 Set 11- mariental
# Processing Record 18 Set 11- saint-leu
# An error occurred skipping..
# Processing Record 19 Set 11- barcelona
# Processing Record 20 Set 11- portsmouth
# Processing Record 21 Set 11- abu kamal
# Processing Record 22 Set 11- kemi
# An error occurred skipping..
# Processing Record 23 Set 11- teluk nibung
# Processing Record 24 Set 11- yol
# Processing Record 25 Set 11- kutum
# Processing Record 26 Set 11- poum
# Processing Record 27 Set 11- oussouye
# Processing Record 28 Set 11- saint-francois
# Processing Record 29 Set 11- hovd
# An error occurred skipping..
# An error occurred skipping..
# Processing Record 30 Set 11- gat
# Processing Record 31 Set 11- port moresby
# Processing Record 32 Set 11- kalianget
# Processing Record 33 Set 11- launceston
# Processing Record 34 Set 11- marquard
# Processing Record 35 Set 11- allschwil
# Processing Record 36 Set 11- doha
# Processing Record 37 Set 11- porangatu
# Processing Record 38 Set 11- sept-iles
# Processing Record 39 Set 11- namatanai
# Processing Record 40 Set 11- shimoda
# Processing Record 41 Set 11- sioux lookout
# Processing Record 42 Set 11- myitkyina
# Processing Record 43 Set 11- semirom
# Processing Record 44 Set 11- bakchar
# Processing Record 45 Set 11- mikhaylovka
# Processing Record 46 Set 11- hashtrud
# Processing Record 47 Set 11- nangomba
# Processing Record 48 Set 11- jalu
# Processing Record 49 Set 11- don matias
# Processing Record 50 Set 11- maceio
# Processing Record 1 Set 12- newtonmore
# Processing Record 2 Set 12- deer lake
# Processing Record 3 Set 12- tambo
# Processing Record 4 Set 12- comodoro rivadavia
# Processing Record 5 Set 12- semme
# Processing Record 6 Set 12- palanga
# Processing Record 7 Set 12- kalach-na-donu
# Processing Record 8 Set 12- pali
# Processing Record 9 Set 12- oranjestad
# Processing Record 10 Set 12- jiuquan
# Processing Record 11 Set 12- paredon
# Processing Record 12 Set 12- dondo
# Processing Record 13 Set 12- wilmington
# Processing Record 14 Set 12- buckeye
# Processing Record 15 Set 12- macklin
# Processing Record 16 Set 12- zarubino
# An error occurred skipping..
# complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": city,
    "lat": lat,
    "lng": lng,
    "max temp": temp,
    "Humidity": Humidity,
    "Cloudiness": Cloudiness,
    "Wind Speed": Wind_Speed,
    "country": country
}
weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv('weather_data.csv')
weather_data.head(15)
# Out:
#                     city    lat     lng  max temp  Humidity  Cloudiness  \
# 0              Dubrovnik  42.65   18.09     87.80        35           0
# 1                   Esso  55.93  158.70     55.89        64          19
# 2           Port Augusta -32.50  137.77     44.60        56         100
# 3                 Lompoc  34.64 -120.46     71.60        60           0
# 4   Vila Franca do Campo  37.72  -25.43     71.60        73          75
# 5                 Avarua -21.21 -159.78     71.60        68          42
# 6           Punta Arenas -53.15  -70.92     39.20        86          90
# 7              Cape Town -33.93   18.42     53.01        87           0
# 8                Ushuaia -54.80  -68.30     42.80        81          40
# 9            Mendeleyevo  56.03   37.22     57.20        87          20
# 10                 Vaini -21.20 -175.20     73.40        73          75
# 11                Kawalu  -7.38  108.21     70.02        91          84
# 12                 Sitka  57.05 -135.33     60.80        82          90
# 13      Praia da Vitória  38.73  -27.07     75.20        64          20
# 14              Tasiilaq  65.61  -37.64     53.60        56          20
#
#     Wind Speed country
# 0        19.46      HR
# 1         3.83      RU
# 2         5.82      AU
# 3        17.22      US
# 4         8.05      PT
# 5         5.82      CK
# 6         3.36      CL
# 7         2.24      ZA
# 8         8.05      AR
# 9        11.18      RU
# 10        8.05      TO
# 11        2.04      ID
# 12       10.29      US
# 13        7.16      PT
# 14        4.70      GL

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
NA=weather_data.Humidity <= 100
NA
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 561    True
# 562    True
# 563    True
# 564    True
# 565    True
# Name: Humidity, Length: 566, dtype: bool

# %%
# Extract relevant fields from the data frame
clean_weather_data=weather_data[NA]

# len(clean_weather_data)
# Export the City_Data into a csv
clean_weather_data.to_csv('clean_weather_data.csv')
clean_weather_data.head(15)
# Out:
#                     city    lat     lng  max temp  Humidity  Cloudiness  \
# 0              Dubrovnik  42.65   18.09     87.80        35           0
# 1                   Esso  55.93  158.70     55.89        64          19
# 2           Port Augusta -32.50  137.77     44.60        56         100
# 3                 Lompoc  34.64 -120.46     71.60        60           0
# 4   Vila Franca do Campo  37.72  -25.43     71.60        73          75
# 5                 Avarua -21.21 -159.78     71.60        68          42
# 6           Punta Arenas -53.15  -70.92     39.20        86          90
# 7              Cape Town -33.93   18.42     53.01        87           0
# 8                Ushuaia -54.80  -68.30     42.80        81          40
# 9            Mendeleyevo  56.03   37.22     57.20        87          20
# 10                 Vaini -21.20 -175.20     73.40        73          75
# 11                Kawalu  -7.38  108.21     70.02        91          84
# 12                 Sitka  57.05 -135.33     60.80        82          90
# 13      Praia da Vitória  38.73  -27.07     75.20        64          20
# 14              Tasiilaq  65.61  -37.64     53.60        56          20
#
#     Wind Speed country
# 0        19.46      HR
# 1         3.83      RU
# 2         5.82      AU
# 3        17.22      US
# 4         8.05      PT
# 5         5.82      CK
# 6         3.36      CL
# 7         2.24      ZA
# 8         8.05      AR
# 9        11.18      RU
# 10        8.05      TO
# 11        2.04      ID
# 12       10.29      US
# 13        7.16      PT
# 14        4.70      GL

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(10,6)) 
plt.scatter(clean_weather_data["lat"], clean_weather_data["max temp"], marker="o", 
            edgecolors="black", c=clean_weather_data["max temp"], cmap='jet')

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
clb = plt.colorbar()
clb.set_label("Global temperature")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_weather_data["lat"], clean_weather_data["Humidity"], marker="o", 
            edgecolors="black", color='lightblue')

# Incorporate the other graph properties
plt.title("Humidity in World Cities")
plt.ylabel("Avg Humidity")
plt.xlabel("Latitude")
# clb = plt.colorbar()
# clb.set_label("Global temperature")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_weather_data["lat"], clean_weather_data["Cloudiness"], marker="o", color='lightblue')

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloud cover")
plt.xlabel("Latitude")
# clb = plt.colorbar()
# clb.set_label("Global temperature")
plt.grid(True)

# Save the figure
plt.savefig("CloudsInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_weather_data["lat"], clean_weather_data["Wind Speed"], marker="o", color='lightgreen')

# Incorporate the other graph properties
plt.title("wind speed in World Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
# clb = plt.colorbar()
# clb.set_label("Global temperature")
plt.grid(True)

# Save the figure
plt.savefig("windInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north = clean_weather_data['lat']>=0
north_df = clean_weather_data[north]

south = clean_weather_data['lat']<=0
south_df = clean_weather_data[south]

north_df.head(10)
# Out:
#                     city    lat     lng  max temp  Humidity  Cloudiness  \
# 0              Dubrovnik  42.65   18.09     87.80        35           0
# 1                   Esso  55.93  158.70     55.89        64          19
# 3                 Lompoc  34.64 -120.46     71.60        60           0
# 4   Vila Franca do Campo  37.72  -25.43     71.60        73          75
# 9            Mendeleyevo  56.03   37.22     57.20        87          20
# 12                 Sitka  57.05 -135.33     60.80        82          90
# 13      Praia da Vitória  38.73  -27.07     75.20        64          20
# 14              Tasiilaq  65.61  -37.64     53.60        56          20
# 15                Dalvik  65.97  -18.53     59.00        72          75
# 21          Beringovskiy  63.05  179.32     51.28        80         100
#
#     Wind Speed country
# 0        19.46      HR
# 1         3.83      RU
# 3        17.22      US
# 4         8.05      PT
# 9        11.18      RU
# 12       10.29      US
# 13        7.16      PT
# 14        4.70      GL
# 15        8.05      IS
# 21        7.36      RU

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(north_df["lat"], north_df["max temp"], marker="o", 
            edgecolors="black", c=north_df["max temp"], cmap='jet')

plt.title("Temperatures in Northern Hemisphere")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
clb = plt.colorbar()
clb.set_label("Temperature")
plt.grid(True)

# plot regression line
x_values = north_df["lat"].astype(float)
y_values = north_df["max temp"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

# Save the figure
plt.savefig("TemperatureInnorthhemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(south_df["lat"], south_df["max temp"], marker="o", 
            edgecolors="black", c=south_df["max temp"], cmap='jet')

plt.title("Temperatures in southern hemisphere")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
clb = plt.colorbar()
clb.set_label("Temperature")
plt.grid(True)


# calculate regression line
x_values = south_df["lat"].astype(float)
y_values = south_df["max temp"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

# Save the figure
plt.savefig("TemperatureInnorthhemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df["lat"].astype(float)
y_values = north_df["Humidity"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Save the figure
plt.savefig("HumidityInnorthhemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df["lat"].astype(float)
y_values = south_df["Humidity"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity in Southern Hemisphere')

# Save the figure
plt.savefig("HumidityInsouthernHemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df["lat"].astype(float)
y_values = north_df["Cloudiness"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,60),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')

# Save the figure
plt.savefig("CloudsInnorthhemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df["lat"].astype(float)
y_values = south_df["Cloudiness"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloud cover')
plt.title('Clouds in Southern Hemisphere')

# Save the figure
plt.savefig("CloudsInsouthernHemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df["lat"].astype(float)
y_values = north_df["Wind Speed"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,14),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Save the figure
plt.savefig("WindInnorthhemisphere.png")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df["lat"].astype(float)
y_values = south_df["Wind Speed"].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind in Southern Hemisphere')

# Save the figure
plt.savefig("WibdInsouthernHemisphere.png")

# Show plot
plt.show()
